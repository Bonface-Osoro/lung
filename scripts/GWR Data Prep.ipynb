# %%
import os
import configparser
import tqdm
import warnings
import pandas as pd
import geopandas as gpd
from shapely import wkt
warnings.filterwarnings('ignore')

# %%
BASE_DIR = os.getcwd()
CONFIG = configparser.ConfigParser()
CONFIG.read(os.path.join(BASE_DIR, 'script_config.ini'))

BASE_PATH = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))

DATA_RAW = os.path.join(BASE_PATH, 'raw')
DATA_RESULTS = os.path.join(BASE_PATH, '..', 'results')

# %% [markdown]
# First we read all the required datasets

# %%
data_path = os.path.join(DATA_RESULTS, 'gwr_data', 'all_gwr_data.csv')

df = pd.read_csv(data_path)
df['mort_count'] = df['mort_count'].fillna(0)

# %% [markdown]
# Before we proceed, let us remove the US territories since we do not have their data. This includes American Samoa, Guam, Northern Mariana, Puerto Rico and Virgin Islands.

# %%
territories = ['AS', 'GU', 'MP', 'PR', 'VI']
df = df[~df['res_statefips'].isin(territories)]
df = df.reset_index(drop = True)

# %% [markdown]
# We are only going to keep the age and sex columns since the occurrence of pulmonary embolism differs with age and maybe sex.

# %%
group_cols = ['county_name', 'state', 'state_fips', 
              'res_countyfips', 'sex', 'county_fips', 
              'res_statefips', 'longitude', 'latitude', 
              'age_cat']

df = (df.groupby(group_cols, as_index = False).agg({
        'mort_count': 'sum',
        'pop20': 'first'}))

# %% [markdown]
# Next, we calculate the mortality counts per a 100,000 people.

# %%
df['mort_per_100k'] = ((df['mort_count'] * 100000) / df['pop20'])#.round().astype(int)

# %% [markdown]
# ### Air Quality Data

# %% [markdown]
# We now include the air quality data

# %%
shp_path = os.path.join(DATA_RAW, 'geodata', 'air_quality.shp')
gdf = gpd.read_file(shp_path)
gdf = gdf[['pm25', 'aqi_value','STATE', 'STATEABBRV', 
           'STATEFIPS', 'COUNTY', 'COUNTYTYPE']]
gdf = gdf.rename(columns = {'pm25': 'pm25_mean',
    'aqi_value': 'air_quality_index', 'COUNTY': 'county_name',
    'STATE': 'state'})
gdf = gdf[~gdf['STATEABBRV'].isin(territories)]
gdf = gdf.reset_index(drop = True)

# %%
df1 = pd.merge(gdf, df, on =['state', 'county_name'], how = 'left')
#df1 = df1.drop(columns = ['state_fips', 'county_fips', 'mort_count'])https://catalog.data.gov/dataset/walkability-index8/resource/89b876c2-934f-4d06-b895-6949edfcb53c

# %% [markdown]
# ### Walkability Index Data

# %% [markdown]
# We also include the walkability index data downloaded from https://catalog.data.gov/dataset/walkability-index8/resource/89b876c2-934f-4d06-b895-6949edfcb53c

# %%
df1
# Out:
#        pm25_mean  air_quality_index      state STATEABBRV STATEFIPS  \
# 0       7.824958          39.653584    Alabama         AL        01
# 1       7.824958          39.653584    Alabama         AL        01
# 2       7.824958          39.653584    Alabama         AL        01
# 3       7.824958          39.653584    Alabama         AL        01
# 4       7.780374          39.967453    Alabama         AL        01
# ...          ...                ...        ...        ...       ...
# 11114   0.000000           0.000000   Virginia         VA        51
# 11115   0.000000           0.000000   Virginia         VA        51
# 11116   0.000000           0.000000   Virginia         VA        51
# 11117   0.000000           0.000000  Wisconsin         WI        55
# 11118   0.000000           0.000000  Wisconsin         WI        55
#
#         county_name COUNTYTYPE  state_fips  res_countyfips  sex  county_fips  \
# 0           Autauga     County         1.0             1.0  0.0          1.0
# 1           Autauga     County         1.0             1.0  0.0          1.0
# 2           Autauga     County         1.0             1.0  1.0          1.0
# 3           Autauga     County         1.0             1.0  1.0          1.0
# 4           Baldwin     County         1.0             3.0  0.0          3.0
# ...             ...        ...         ...             ...  ...          ...
# 11114    Waynesboro       City         NaN             NaN  NaN          NaN
# 11115  Williamsburg       City         NaN             NaN  NaN          NaN
# 11116    Winchester       City         NaN             NaN  NaN          NaN
# 11117         Pepin     County        55.0            91.0  0.0         91.0
# 11118         Pepin     County        55.0            91.0  1.0         91.0
#
#       res_statefips  longitude   latitude  age_cat  mort_count     pop20  \
# 0                AL -86.642759  32.534932      2.0         5.0   58764.0
# 1                AL -86.642759  32.534932      3.0        15.0   58764.0
# 2                AL -86.642759  32.534932      2.0         4.0   58764.0
# 3                AL -86.642759  32.534932      3.0         9.0   58764.0
# 4                AL -87.723352  30.736470      1.0         1.0  231365.0
# ...             ...        ...        ...      ...         ...       ...
# 11114           NaN        NaN        NaN      NaN         NaN       NaN
# 11115           NaN        NaN        NaN      NaN         NaN       NaN
# 11116           NaN        NaN        NaN      NaN         NaN       NaN
# 11117            WI -92.001564  44.582933      3.0         2.0    7313.0
# 11118            WI -92.001564  44.582933      3.0         2.0    7313.0
#
#        mort_per_100k
# 0           8.508611
# 1          25.525832
# 2           6.806889
# 3          15.315499
# 4           0.432217
# ...              ...
# 11114            NaN
# 11115            NaN
# 11116            NaN
# 11117      27.348557
# 11118      27.348557
#
# [11119 rows x 18 columns]

# %%
walk_path = os.path.join(DATA_RAW, 'geodata', 'walkability_index.shp')
wki = gpd.read_file(walk_path)
wki = wki.rename(columns = {'STATEFP': 'county_name',
    'STATE_NAME': 'state', 'mean': 'walkability_index'})
wki
# Out:
#         OBJECTID STATEFP COUNTYFP  NatWalkInd    Shape_Leng    Shape_Area  \
# 0            1.0      48      113   14.000000   3110.360820  2.978361e+05
# 1            2.0      48      113   10.833333   3519.469110  4.849451e+05
# 2            3.0      48      113    8.333333   1697.091802  1.067059e+05
# 3            4.0      48      113   15.666667   2922.609204  4.818284e+05
# 4            5.0      48      113   10.166667   3731.971773  6.876848e+05
# ...          ...     ...      ...         ...           ...           ...
# 220734  220735.0      78      030    7.333333   3414.446949  3.355857e+05
# 220735  220736.0      78      030    7.333333   2421.025608  2.924305e+05
# 220736  220737.0      78      030    7.333333   1955.909418  1.619395e+05
# 220737  220738.0      78      030    4.000000  16896.768872  1.038966e+07
# 220738  220739.0      78      030    4.666667   3890.488237  6.114601e+05
#
#                                                  geometry
# 0       POLYGON ((-6.9e+04 1.09e+06, -6.9e+04 1.09e+06...
# 1       POLYGON ((-6.89e+04 1.09e+06, -6.89e+04 1.09e+...
# 2       POLYGON ((-6.81e+04 1.09e+06, -6.81e+04 1.09e+...
# 3       POLYGON ((-6.9e+04 1.09e+06, -6.9e+04 1.09e+06...
# 4       POLYGON ((-6.9e+04 1.09e+06, -6.9e+04 1.09e+06...
# ...                                                   ...
# 220734  POLYGON ((3.35e+06 5.01e+04, 3.35e+06 5.01e+04...
# 220735  POLYGON ((3.35e+06 5.12e+04, 3.35e+06 5.12e+04...
# 220736  POLYGON ((3.35e+06 5.13e+04, 3.35e+06 5.13e+04...
# 220737  MULTIPOLYGON (((3.36e+06 5.04e+04, 3.36e+06 5....
# 220738  POLYGON ((3.35e+06 5.27e+04, 3.35e+06 5.27e+04...
#
# [220739 rows x 7 columns]

# %%
df2 = pd.merge(df1, wki, on =['state', 'county_name'], how = 'left')

# %% [markdown]
# ### Poverty and Income Data

# %% [markdown]
# We also include poverty and income data https://www.census.gov/data/datasets/2023/demo/saipe/2023-state-and-county.html

# %%
inc_path = os.path.join(DATA_RAW, 'poverty_income.csv')
povin = pd.read_csv(inc_path)
povin = povin[['res_statefips', 'county_name', 
               'poverty_estimate', 'poverty_perc', 
               'median_income']]
povin['county_name'] = povin['county_name'].str.replace(r'\s*county\s*', '', 
                       case = False, regex = True).str.strip()

# %%
df3 = pd.merge(df2, povin, on =['res_statefips', 'county_name'], how = 'left')
df3
# Out:
#        pm25_mean  air_quality_index      state STATEABBRV STATEFIPS  \
# 0       7.824958          39.653584    Alabama         AL        01
# 1       7.824958          39.653584    Alabama         AL        01
# 2       7.824958          39.653584    Alabama         AL        01
# 3       7.824958          39.653584    Alabama         AL        01
# 4       7.780374          39.967453    Alabama         AL        01
# ...          ...                ...        ...        ...       ...
# 11114   0.000000           0.000000   Virginia         VA        51
# 11115   0.000000           0.000000   Virginia         VA        51
# 11116   0.000000           0.000000   Virginia         VA        51
# 11117   0.000000           0.000000  Wisconsin         WI        55
# 11118   0.000000           0.000000  Wisconsin         WI        55
#
#         county_name COUNTYTYPE  res_countyfips  sex res_statefips  longitude  \
# 0           Autauga     County             1.0  0.0            AL -86.642759
# 1           Autauga     County             1.0  0.0            AL -86.642759
# 2           Autauga     County             1.0  1.0            AL -86.642759
# 3           Autauga     County             1.0  1.0            AL -86.642759
# 4           Baldwin     County             3.0  0.0            AL -87.723352
# ...             ...        ...             ...  ...           ...        ...
# 11114    Waynesboro       City             NaN  NaN           NaN        NaN
# 11115  Williamsburg       City             NaN  NaN           NaN        NaN
# 11116    Winchester       City             NaN  NaN           NaN        NaN
# 11117         Pepin     County            91.0  0.0            WI -92.001564
# 11118         Pepin     County            91.0  1.0            WI -92.001564
#
#         latitude  age_cat     pop20  mort_per_100k  walkability_index  \
# 0      32.534932      2.0   58764.0       8.508611           4.826667
# 1      32.534932      3.0   58764.0      25.525832           4.826667
# 2      32.534932      2.0   58764.0       6.806889           4.826667
# 3      32.534932      3.0   58764.0      15.315499           4.826667
# 4      30.736470      1.0  231365.0       0.432217           6.038690
# ...          ...      ...       ...            ...                ...
# 11114        NaN      NaN       NaN            NaN                NaN
# 11115        NaN      NaN       NaN            NaN                NaN
# 11116        NaN      NaN       NaN            NaN                NaN
# 11117  44.582933      3.0    7313.0      27.348557           5.208333
# 11118  44.582933      3.0    7313.0      27.348557           5.208333
#
#       poverty_estimate poverty_perc median_income
# 0                7,004         11.7        68,857
# 1                7,004         11.7        68,857
# 2                7,004         11.7        68,857
# 3                7,004         11.7        68,857
# 4               24,942           10        74,248
# ...                ...          ...           ...
# 11114              NaN          NaN           NaN
# 11115              NaN          NaN           NaN
# 11116              NaN          NaN           NaN
# 11117              762         10.3        70,012
# 11118              762         10.3        70,012
#
# [11119 rows x 19 columns]

# %% [markdown]
# ### Heart Disease Data

# %% [markdown]
# We also include heart disease mortality data from US Department of Health and Human Services https://catalog.data.gov/dataset/heart-disease-mortality-data-among-us-adults-35-by-state-territory-and-county-2019-2021

# %%
hd_path = os.path.join(DATA_RAW, 'heart_disease_mortality_geo.csv')
hd = pd.read_csv(hd_path)
hd = hd[['state', 'county_name', 'heart_mort_100k']]
df4 = pd.merge(df3, hd, on =['state', 'county_name'], how = 'left')
df4
# Out:
#        pm25_mean  air_quality_index      state STATEABBRV STATEFIPS  \
# 0       7.824958          39.653584    Alabama         AL        01
# 1       7.824958          39.653584    Alabama         AL        01
# 2       7.824958          39.653584    Alabama         AL        01
# 3       7.824958          39.653584    Alabama         AL        01
# 4       7.780374          39.967453    Alabama         AL        01
# ...          ...                ...        ...        ...       ...
# 11138   0.000000           0.000000   Virginia         VA        51
# 11139   0.000000           0.000000   Virginia         VA        51
# 11140   0.000000           0.000000   Virginia         VA        51
# 11141   0.000000           0.000000  Wisconsin         WI        55
# 11142   0.000000           0.000000  Wisconsin         WI        55
#
#         county_name COUNTYTYPE  res_countyfips  sex res_statefips  longitude  \
# 0           Autauga     County             1.0  0.0            AL -86.642759
# 1           Autauga     County             1.0  0.0            AL -86.642759
# 2           Autauga     County             1.0  1.0            AL -86.642759
# 3           Autauga     County             1.0  1.0            AL -86.642759
# 4           Baldwin     County             3.0  0.0            AL -87.723352
# ...             ...        ...             ...  ...           ...        ...
# 11138    Waynesboro       City             NaN  NaN           NaN        NaN
# 11139  Williamsburg       City             NaN  NaN           NaN        NaN
# 11140    Winchester       City             NaN  NaN           NaN        NaN
# 11141         Pepin     County            91.0  0.0            WI -92.001564
# 11142         Pepin     County            91.0  1.0            WI -92.001564
#
#         latitude  age_cat     pop20  mort_per_100k  walkability_index  \
# 0      32.534932      2.0   58764.0       8.508611           4.826667
# 1      32.534932      3.0   58764.0      25.525832           4.826667
# 2      32.534932      2.0   58764.0       6.806889           4.826667
# 3      32.534932      3.0   58764.0      15.315499           4.826667
# 4      30.736470      1.0  231365.0       0.432217           6.038690
# ...          ...      ...       ...            ...                ...
# 11138        NaN      NaN       NaN            NaN                NaN
# 11139        NaN      NaN       NaN            NaN                NaN
# 11140        NaN      NaN       NaN            NaN                NaN
# 11141  44.582933      3.0    7313.0      27.348557           5.208333
# 11142  44.582933      3.0    7313.0      27.348557           5.208333
#
#       poverty_estimate poverty_perc median_income  heart_mort_100k
# 0                7,004         11.7        68,857            410.9
# 1                7,004         11.7        68,857            410.9
# 2                7,004         11.7        68,857            410.9
# 3                7,004         11.7        68,857            410.9
# 4               24,942           10        74,248            358.1
# ...                ...          ...           ...              ...
# 11138              NaN          NaN           NaN              NaN
# 11139              NaN          NaN           NaN              NaN
# 11140              NaN          NaN           NaN              NaN
# 11141              762         10.3        70,012            311.7
# 11142              762         10.3        70,012            311.7
#
# [11143 rows x 20 columns]

# %%
folder_out = os.path.join(DATA_RESULTS, 'gwr_data')
filename = 'full_gwr_ready_data.csv'
path_out = os.path.join(folder_out, filename)
df4.to_csv(path_out, index = False)
