# %%
import os
import configparser
import tqdm
import pandas as pd
import geopandas as gpd

# %%
BASE_DIR = os.getcwd()
CONFIG = configparser.ConfigParser()
CONFIG.read(os.path.join(BASE_DIR, 'script_config.ini'))

BASE_PATH = os.path.abspath(os.path.join(os.getcwd(), '..', 'data'))

DATA_RAW = os.path.join(BASE_PATH, 'raw')
DATA_RESULTS = os.path.join(BASE_PATH, '..', 'results')

# %% [markdown]
# We access the air quality data downloaded from https://www.epa.gov/outdoor-air-quality-data/download-daily-data

# %%
air_path = os.path.join(DATA_RAW, 'air_quality')
files = os.listdir(air_path)

# %%
dfs = []

for file in files:
    
    state_path = os.path.join(air_path, file)
    df = pd.read_csv(state_path)
    df = df[['Daily Mean PM2.5 Concentration', 
             'Units', 'Daily AQI Value', 'State', 
             'County', 'Site Latitude', 'Site Longitude']]
    grouped_df = (
        df.groupby(['State', 'County', 'Units', 'Site Latitude', 'Site Longitude'], as_index=False)
          .agg({'Daily Mean PM2.5 Concentration': 'mean',
              'Daily AQI Value': 'mean'}))
    dfs.append(grouped_df)

# %% [markdown]
# Combine air quality data

# %%
dfs = pd.concat(dfs, ignore_index=True)
folder_out = os.path.join(DATA_RESULTS, 'final')

filename = 'air_quality_data.csv'
path_out = os.path.join(folder_out, filename)
dfs.to_csv(path_out, index = False)
dfs
# Out:
#           State       County     Units  Site Latitude  Site Longitude  \
# 0     Minnesota        Anoka  ug/m3 LC      45.137680      -93.207615
# 1     Minnesota       Becker  ug/m3 LC      46.851811      -95.846272
# 2     Minnesota     Beltrami  ug/m3 LC      47.878159      -95.029172
# 3     Minnesota      Carlton  ug/m3 LC      46.713694      -92.511722
# 4     Minnesota         Cass  ug/m3 LC      47.384430      -94.601660
# ...         ...          ...       ...            ...             ...
# 1260    Montana      Sanders  ug/m3 LC      47.594395     -115.323746
# 1261    Montana      Sanders  ug/m3 LC      47.954771     -115.671925
# 1262    Montana     Sheridan  ug/m3 LC      48.487054     -104.476346
# 1263    Montana   Silver Bow  ug/m3 LC      46.002602     -112.501247
# 1264    Montana  Yellowstone  ug/m3 LC      45.806311     -108.425978
#
#       Daily Mean PM2.5 Concentration  Daily AQI Value
# 0                           5.986638        31.491379
# 1                           5.297953        28.149123
# 2                           4.651156        25.300578
# 3                           1.348406         9.028986
# 4                           5.858908        31.692529
# ...                              ...              ...
# 1260                        8.119452        39.172603
# 1261                        4.029126        17.184466
# 1262                        3.600000        19.337079
# 1263                        7.982512        34.815271
# 1264                        6.702740        33.939726
#
# [1265 rows x 7 columns]

# %%
pul_path = os.path.join(DATA_RESULTS, 'final', 'pulmonary_full_data.csv')
df2 = pd.read_csv(pul_path)
# Out:
#          fips_new res_statefips  \
# 0            6093            CA
# 1            6093            CA
# 2            6093            CA
# 3            6093            CA
# 4            6093            CA
# ...           ...           ...
# 1179092     12087            FL
# 1179093     12087            FL
# 1179094     12087            FL
# 1179095     12087            FL
# 1179096     12087            FL
#
#                                                geometry county_name  \
# 0        POINT (-2167649.2049579737 2370072.9761748626)     Alameda
# 1        POINT (-2167649.2049579737 2370072.9761748626)     Alameda
# 2        POINT (-2167649.2049579737 2370072.9761748626)     Alameda
# 3        POINT (-2167649.2049579737 2370072.9761748626)     Alameda
# 4        POINT (-2167649.2049579737 2370072.9761748626)     Alameda
# ...                                                 ...         ...
# 1179092    POINT (1514598.4786629865 385973.2843747351)  Washington
# 1179093    POINT (1514598.4786629865 385973.2843747351)  Washington
# 1179094    POINT (1514598.4786629865 385973.2843747351)  Washington
# 1179095    POINT (1514598.4786629865 385973.2843747351)  Washington
# 1179096    POINT (1514598.4786629865 385973.2843747351)  Washington
#
#          state_fips  res_countyfips sex     race_recode3            age_cat  \
# 0                 6               1   F            Black      30 - 49 years
# 1                 6               1   F            Black  70 years or above
# 2                 6               1   F  Non-White/Black      10 - 29 years
# 3                 6               1   F  Non-White/Black      30 - 49 years
# 4                 6               1   F  Non-White/Black  70 years or above
# ...             ...             ...  ..              ...                ...
# 1179092          12             133   F            Black      10 - 29 years
# 1179093          12             133   F            White  70 years or above
# 1179094          12             133   M            Black      30 - 49 years
# 1179095          12             133   M            White      30 - 49 years
# 1179096          12             133   M            White  70 years or above
#
#          mortality_count
# 0                     10
# 1                     23
# 2                      1
# 3                      3
# 4                      5
# ...                  ...
# 1179092                1
# 1179093                3
# 1179094                1
# 1179095                1
# 1179096                2
#
# [1179097 rows x 10 columns]

# %%
dfs = dfs[['County', 'Units', 'Daily Mean PM2.5 Concentration', 'Daily AQI Value']]
dfs.rename(columns = {'County': 'county_name'}, inplace = True)
# Out:
# /var/folders/26/c8kdf2_x3x5bcbqcrtq4hml80000gn/T/ipykernel_66580/1337554542.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs.rename(columns = {'County': 'county_name'}, inplace = True)

# %%
df2 = df2.merge(dfs, on = "county_name", how = 'inner')
filename = 'pulmonary_air_quality_data.csv'
path_out = os.path.join(folder_out, filename)
df2.to_csv(path_out, index = False)
